# %% [markdown]
# ## Fonctions en Python

# %% [markdown]
# ### 1. Rappels

# %% [markdown]
# Ce fichier un &laquo; notebook Jupyter &raquo; qu'on peut ouvrir avec :
# - `Jupyter Notebook` sur PC ou Mac (mais cela nécessite une installation) ;
# - l'application `Carnets` sur iPad ;
# - l'application `Pydroid` sur Android.
#
# Des tutoriels sont disponibles dans la section `Notebooks Jupyter` du cours sur Moodle.

# %% [markdown]
# Un notebook Jupyter est composé de plusieurs cellules. Certaines d'entre elles peuvent contenir du texte (comme cette cellule), d'autres peuvent contenir du code Python qu'on peut exécuter en :
# - appuyant sur `Maj + Entrée` ;
# - appuyant sur `Ctrl + Entrée` ;
# - en cliquant sur l'icône `>| Run` du menu.

# %% [markdown]
# Pour changer le type d'une cellule, on utilise encore un menu déroulant :
#
# ![Screen%20Capture_select-area_20200906194852.png](attachment:Screen%20Capture_select-area_20200906194852.png)
#
# Pour taper du code Python, on utilise des cellules du type `Code` tandis que pour écrire du texte, on utilise des cellules du type `Markdown`.

# %% [markdown]
# ### 2. Fonctions en Python

# %% [markdown]
# #### 2.1 Définir une fonction &ndash; Un exemple

# %% [markdown]
# Dans la cellule suivante, nous allons écrire une fonction en Python :

# %%
def f(a):
    b = a * a
    return b

# %% [markdown]
# **Exercice 1**
# 1. Insérer deux cellules après celle-ci.
# 2. Que renvoient ``f(3)`` et ``f(10)`` (écrire une instruction par cellule puis l'exécuter).

# %% [markdown]
# 3. Double-cliquer sur cette cellule contenant du texte, puis compléter le texte ci-dessous. Une fois le texte complété, exécuter la cellule.
#   - *Pour définir une fonction en Python, on utilise le mot-clé ...*
#   - *La fonction définie précédémment s'appelle ...*
#   - *Elle possède un paramètre ``a`` et renvoie le carré de ce paramètre.*
#   - *On utilise le mot-clé ... pour préciser ce qu'une fonction renvoie.*

# %% [markdown]
# **2.2 Pourquoi utiliser des fonctions ?**

# %% [markdown]
# On utilise des fonctions pour (entre autres) :
# - effectuer des calculs/opérations répétitives sans avoir à ressaisir les mêmes instructions à chaque fois ;
# - découper un programme &laquo; compliqué &raquo; en parties plus simples ;
# - rendre un programme plus lisible.

# %% [markdown]
# #### 2.3 Exercices

# %% [markdown]
# **Exercice 2**
# On définit une fonction dans la cellule suivante :

# %%
def mystere(c):
    return 2 * c * (c + 4)

# %% [markdown]
# 1. Comment s'appelle cette fonction ?
# 2. Combien a-t-elle de paramètres ?
# 3. Que renvoient les appels ``mystere(1)``, ``mystere(2)`` et ``3 * mystere(1) + 4`` ? (essayer de répondre sans utiliser le notebook dans un 1er temps puis vérifier)

# %% [markdown]
# **Exercice 3**
# La fonction suivante renvoie plusieurs résultats, séparés avec des virgules :

# %%
def puissances(x):
    carre = x * x
    cube = x * x * x
    return x, carre, cube

# %% [markdown]
# 1. Comment s'appelle cette fonction ?
# 2. Combien a-t-elle de paramètres ?
# 3. Combien de résultats renvoie-t-elle ?
# 4. Qu'obtient-on grâce à ``puissances(5)`` ? (essayer de répondre sans utiliser le notebook puis vérifier)

# %% [markdown]
# **Exercice 4**
# On souhaite écrire une fonction ``perimetre`` qui renvoie le périmètre d'un rectangle dont la longueur ``L`` et la largeur ``l`` sont donnés en paramètres de la fonction.
# Compléter le code ci-dessous (effacer ``pass`` puis compléter le code).

# %%
def perimetre(L, l):
    pass

# %% [markdown]
# **Exercice 5**
# Un véhicule parcourt une distance ``d`` (en km) pendant une durée ``t`` (en heure).

# %%
def v(d, t):
    return d / t

# %% [markdown]
# 1. Que fait la fonction précédente ?
# 2. Que permet de calculer l'appel ``v(120, 2)`` ?

# %% [markdown]
# **Exercice 6**
# Insérer une cellule après celle-ci, puis écrire une fonction ``aire`` permettant de calculer l'aire d'un triangle dont la base ``b`` et la hauteur ``h`` sont donnés en paramètres.

# %% [markdown]
# **Exercice 7**
# L'indice de masse corporelle (ou IMC) est une grandeur qui permet d'estimer la corpulence d'une personne. Il s'obtient en divisant la masse (en kg) de la personne par le carré de sa taille (en m).
#
# | IMC (kg.m$^{-2}$) 	|      Interprétation     	|
# |:-----------------:	|:-----------------------:	|
# |   moins de 16,5   	| anorexie ou dénutrition 	|
# |   de 16,5 à 18,5  	|         maigreur        	|
# |    de 18,5 à 25   	|       poids normal      	|
# |     de 25 à 30    	|         surpoids        	|
# |     de 30 à 35    	|     obésité modérée     	|
# |     de 35 à 40    	|      obésité sévère     	|
# |     plus de 40    	|     obésité morbide     	|

# %% [markdown]
# 1. Insérer deux cellules après celle-ci, puis écrire deux calculs (un par cellule) permettant de calculer l'IMC :
#   - d'une personne pesant 95 kg et mesurant 1,81 m ;
#   - d'une personne pesant 48 kg et mesurant 1,69m.

# %% [markdown]
# 2. Compléter la fonction ``imc`` ci-dessous afin qu'elle renvoie l'IMC d'une personne de masse ``m`` (en kg) et de taille ``t`` (en m).

# %%
# Comme précédemment, effacer pass puis compléter le code
def imc(m, t):
    pass

# %% [markdown]
# **Exercice 8**
# Kiivai a écrit une fonction ``cube`` qui permet de calculer le cube d'un nombre :

# %%
def cube(t)
    x = x ** 3
return x

# %% [markdown]
# Corriger les erreurs commises par Kiivai.

# %% [markdown]
# **Exercice 9**
# Soit $h$ la fonction définie sur $\mathbb{R}$ par $h(x)=2x-4$.
# 1. La fonction $h$ est une fonction ...

# %% [markdown]
# 2. Écrire une fonction Python nommée ``h`` permettant de calculer l'image d'un nombre par la fonction précédente.

# %%
# Effacer pass puis compléter le code
def h(x):
    pass

# %% [markdown]
# 3. Citer des différences entre les fonctions comme celles qui sont étudiées en mathématiques et les fonctions &laquo; informatiques &raquo; Python.
