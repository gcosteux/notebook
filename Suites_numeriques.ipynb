# %% [markdown]
# ## Suites numériques en Python

# %% [markdown]
# ### 1. Rappels

# %% [markdown]
# Ce fichier un &laquo; notebook Jupyter &raquo; qu'on peut ouvrir avec :
# - `Jupyter Notebook` sur PC ou Mac (mais cela nécessite une installation) ;
# - l'application `Carnets` sur iPad ;
# - l'application `Pydroid` sur Android.
#
# Des tutoriels sont disponibles dans la section `Notebooks Jupyter` du cours sur Moodle.

# %% [markdown]
# Un notebook Jupyter est composé de plusieurs cellules. Certaines d'entre elles peuvent contenir du texte (comme cette cellule), d'autres peuvent contenir du code Python qu'on peut exécuter en :
# - appuyant sur `Maj + Entrée` ;
# - appuyant sur `Ctrl + Entrée` ;
# - en cliquant sur l'icône `>| Run` du menu.

# %% [markdown]
# Pour changer le type d'une cellule, on utilise encore un menu déroulant :
# Pour taper du code Python, on utilise des cellules du type `Code` tandis que pour écrire du texte, on utilise des cellules du type `Markdown`.

# %% [markdown]
# ### 2. Fonctions en Python

# %% [markdown]
# #### Définir une fonction &ndash; Un exemple

# %% [markdown]
# Dans la cellule suivante, nous allons écrire une fonction en Python :

# %%
def f(a):
    b = a * a
    return b

# %% [markdown]
# **Exercice 1**
# 1. Insérer deux cellules après celle-ci ( Menu ``Insérer`` ou bouton de raccourci ``[+]``)
# 2. Que renvoient ``f(3)`` et ``f(10)`` (écrire une instruction par cellule puis l'exécuter).

# %% [markdown]
# 3. Double-cliquer sur cette cellule contenant du texte, puis compléter le texte ci-dessous. Une fois le texte complété, exécuter la cellule.
#   - *Pour définir une fonction en Python, on utilise le mot-clé ...*
#   - *La fonction définie précédémment s'appelle ...*
#   - *Elle possède un paramètre ``a`` et renvoie le carré de ce paramètre.*
#   - *On utilise le mot-clé ... pour préciser ce qu'une fonction renvoie.*

# %% [markdown]
# **2.2 Pourquoi utiliser des fonctions ?**

# %% [markdown]
# On utilise des fonctions pour (entre autres) :
# - effectuer des calculs/opérations répétitives sans avoir à ressaisir les mêmes instructions à chaque fois ;
# - découper un programme &laquo; compliqué &raquo; en parties plus simples ;
# - rendre un programme plus lisible.

# %% [markdown]
# **Exercice 2**
# On définit une fonction dans la cellule suivante :

# %%
def mystere(c):
    return 2 * c * (c + 4)

# %% [markdown]
# 1. Comment s'appelle cette fonction ? (répondre ici)
# 2. Combien a-t-elle de paramètres ?
# 3. Combien renvoie-t-elle de résultats ?
# 4. Que renvoie ``3 * mystere(1) + 4`` ? (essayer de répondre sans utiliser le notebook dans un 1er temps puis vérifier en saisissant l'instruction dans une nouvelle cellule)

# %% [markdown]
# **Exercice 3**
# Une fonction Python peut renvoyer plusieurs résultats affichés dans une liste par exemple :

# %%
def puissances(x):
    carre = x * x
    cube = x * x * x
    liste=[x,carre,cube] #une liste se note entre crochets.
    #print(liste[0])
    #print(liste[1])
    #print(liste[2])
    return liste

# %% [markdown]
# 1. Comment s'appelle cette fonction ?
# 2. Combien a-t-elle de paramètres ?
# 3. Qu'obtient-on grâce à ``puissances(5)`` ? (essayer de répondre sans utiliser le notebook puis vérifier)
# 4. En supprimant les # dans le programme précédent, noter quelle valeur renvoie liste[0] puis liste[1] et liste[2]

# %% [markdown]
# ### 3. Boucle POUR... (FOR...) en Python

# %% [markdown]
# **Exercice 4**
# Kiivai a écrit une fonction ``cube`` qui permet de calculer le cube d'un nombre :

# %%
def cube(t)
    x = x ** 3
    return x

# %% [markdown]
# 1. Dans une nouvelle cellule, saisir ``cube(10)`` et vérifier si le programme renvoie 1000. Corriger les erreurs commises par Kiivai puis exécuter à nouveau les cellules.
# 2. Executer le programme ``suite_cube(n)`` qui, à l'aide de l'instruction ``for``, calcule et affiche les n premiers cubes entiers positifs, puis dans une autre cellule, saisir ``suite_cube(5)``. Qu'affiche cette instruction?

# %%
def suite_cube(n):
    for i in range(n):    #instruction pour répéter n fois une action
        print("le cube de ",i," est égale à ",cube(i))    #instruction pour afficher cube(i). i est une variable qui automatiquement s'incrémente de 1

# %% [markdown]
# **Exercice 5**
# Soit $h$ la fonction définie sur $\mathbb{R}$ par $h(x)=2x-4$.
# 1. La fonction $h$ est une fonction (compléter par le mot qui convient) ...

# %% [markdown]
# 2. Écrire une fonction Python nommée ``h`` permettant de calculer l'image d'un nombre par la fonction précédente.

# %%
# Effacer pass puis compléter le code. 
# Ceci est un commentaire (précédé d'un #) qui n'est pas pris en compte par le programme
def h(x):
    pass

# %% [markdown]
# 3. Cette fois, on souhaite copier chaque terme h(0), h(1), h(2) etc... dans une liste L, entre crochets. A savoir que L[0] correspond au terme initial de la liste L, L[1] le terme suivant etc...   Exécuter les deux cellules suivantes puis expliquer ce que renvoie ``suite_h(5)``.

# %%
def suite_h(n):
    L=[]                   #on initialise la liste à une liste vide
    for i in range(n):
        L.append(h(i))     # l'instruction append permet de rajouter à L, au fur et à mesure de la boucle, l'élément h(i)
    print(L)

# %%
suite_h(5)

# %% [markdown]
# **exercice 6**   Soit w la suite définie par w(0)=4, w(1)=3*w(0)-10, w(2)=3*w(1)-10, w(3)=3*w(2)-10 etc ... et ainsi de suite. De manière générale w(n+1)=3*w(n)-10.
# Ecrire un programme ``suite_w()`` qui affiche les n premiers termes de la suite w
